# %%
import pandas as pd
import openpyxl

# Read Data (text file)
df = pd.read_csv('genome_hu0B4CF6_out.txt', sep='\t', header=0 , encoding='utf-8')
# Out:
# /tmp/ipykernel_32487/3655771701.py:5: DtypeWarning: Columns (1,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('genome_hu0B4CF6_out.txt', sep='\t', header=0 , encoding='utf-8')

# %%
print(df.columns)
# Out:
# Index(['# inDBSNPOrNot', 'chromosome', 'position', 'referenceBase',
#        'sampleGenotype', 'sampleAlleles', 'allelesDBSNP', 'accession',
#        'functionGVS', 'functionDBSNP', 'rsID', 'aminoAcids', 'proteinPosition',
#        'cDNAPosition', 'polyPhen', 'granthamScore', 'consScoreGERP',
#        'scoreCADD', 'chimpAllele', 'geneList', 'dbSNPValidation',
#        'repeatMasker', 'tandemRepeat', 'clinicalAssociation',
#        'distanceToSplice', 'microRNAs', 'keggPathway', 'cpgIslands',
#        'genomesESP', 'genomesExAC', 'PPI', 'proteinAccession'],
#       dtype='object')

# %%
# Summary of Data
print("Data Summary:")
print(df.describe())
print(df.info())
print(df.head())
print(df.tail())
print(df.columns)
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())
print(df.columns.tolist())
#print(df.index.tolist())
print(df.dtypes)
print(df.memory_usage(deep=True))
print(df.sample(5))
print(df.sample(frac=0.1))
# Out:
# Data Summary:
#              817341       3131972           NA.1          NA.2           NA.3  \
# count  6.838310e+05  6.838310e+05   26047.000000  14832.000000  671548.000000
# mean   7.581041e+07  1.429199e+07    2206.086881     66.060343      -0.720744
# std    5.916621e+07  2.573205e+07    4718.198032     42.417780       2.671309
# min    1.209100e+04  4.700000e+01       1.000000      5.000000     -12.300000
# 25%    2.647033e+07  2.148034e+06     490.000000     29.000000      -2.130000
# 50%    6.417220e+07  6.677649e+06    1072.000000     58.000000      -0.317000
# 75%    1.131588e+08  1.113088e+07    2265.500000     91.000000       0.970000
# max    2.489146e+08  7.553197e+08  103781.000000    215.000000       6.170000
#
#        NA.4           862
# count   0.0  6.838310e+05
# mean    NaN  2.632269e+04
# std     NaN  7.654784e+04
# min     NaN  0.000000e+00
# 25%     NaN  1.072000e+03
# 50%     NaN  5.222000e+03
# 75%     NaN  2.060150e+04
# max     NaN  1.620541e+06
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683831 entries, 0 to 683830
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   dbSNP_2002                   683831 non-null  object
#  1   1                            683831 non-null  object
#  2   817341                       683831 non-null  int64
#  3   A                            683831 non-null  object
#  4   R                            683831 non-null  object
#  5   A/G                          683831 non-null  object
#  6   A/C/G/T                      683831 non-null  object
#  7   none                         683831 non-null  object
#  8   upstream-gene                683831 non-null  object
#  9   upstream_transcript_variant  683831 non-null  object
#  10  3131972                      683831 non-null  int64
#  11  none.1                       683831 non-null  object
#  12  NA                           23447 non-null   object
#  13  NA.1                         26047 non-null   float64
#  14  unknown                      683831 non-null  object
#  15  NA.2                         14832 non-null   float64
#  16  NA.3                         671548 non-null  float64
#  17  3.952                        683831 non-null  object
#  18  A.1                          683831 non-null  object
#  19  none.2                       683831 non-null  object
#  20  NA.4                         0 non-null       float64
#  21  none.3                       683831 non-null  object
#  22  none.4                       683831 non-null  object
#  23  unknown.1                    683831 non-null  object
#  24  862                          683831 non-null  int64
#  25  none.5                       683831 non-null  object
#  26  unknown.2                    683831 non-null  object
#  27  none.6                       683831 non-null  object
#  28  unknown.3                    683831 non-null  object
#  29  unknown.4                    683831 non-null  object
#  30  none.7                       683831 non-null  object
#  31  NA.5                         23520 non-null   object
# dtypes: float64(4), int64(3), object(25)
# memory usage: 167.0+ MB
# None
#    dbSNP_2002  1  817341  A  R  A/G A/C/G/T         none    upstream-gene  \
# 0  dbSNP_2004  1  820888  G  A  A/A     G/A         none  downstream-gene
# 1  dbSNP_2004  1  841166  A  R  A/G     A/G  NR_047519.1           intron
# 2  dbSNP_2004  1  841166  A  R  A/G     A/G  NR_047521.1           intron
# 3  dbSNP_2004  1  841166  A  R  A/G     A/G  NR_047523.1           intron
# 4  dbSNP_2004  1  841166  A  R  A/G     A/G  NR_047524.1           intron
#
#   upstream_transcript_variant  ...  none.4 unknown.1   862  none.5 unknown.2  \
# 0                     unknown  ...    none   unknown  2166    none   unknown
# 1              intron_variant  ...    none   unknown    32    none   unknown
# 2              intron_variant  ...    none   unknown    32    none   unknown
# 3              intron_variant  ...    none   unknown    32    none   unknown
# 4              intron_variant  ...    none   unknown    32    none   unknown
#
#    none.6  unknown.3 unknown.4 none.7 NA.5
# 0    none    unknown   unknown   none  NaN
# 1    none    unknown   unknown   none  NaN
# 2    none    unknown   unknown   none  NaN
# 3    none    unknown   unknown   none  NaN
# 4    none    unknown   unknown   none  NaN
#
# [5 rows x 32 columns]
#        dbSNP_2002  1    817341  A  R  A/G A/C/G/T            none  \
# 683826       none  Y  57185486  G  R  G/A     G/A  XM_017030050.1
# 683827       none  Y  57185486  G  R  G/A     G/A  XM_017030051.1
# 683828       none  Y  57185486  G  R  G/A     G/A  XM_017030052.1
# 683829       none  Y  57185486  G  R  G/A     G/A  XM_017030053.1
# 683830       none  Y  57185486  G  R  G/A     G/A  XM_017030054.1
#
#        upstream-gene upstream_transcript_variant  ...  none.4 unknown.1  862  \
# 683826        intron                     unknown  ...    none   unknown  250
# 683827        intron                     unknown  ...    none   unknown  250
# 683828        intron                     unknown  ...    none   unknown  250
# 683829        intron                     unknown  ...    none   unknown  250
# 683830        intron                     unknown  ...    none   unknown  250
#
#         none.5                                          unknown.2  none.6  \
# 683826    none  hsa04060:Cytokine-cytokineReceptorInteraction;...    none
# 683827    none  hsa04060:Cytokine-cytokineReceptorInteraction;...    none
# 683828    none  hsa04060:Cytokine-cytokineReceptorInteraction;...    none
# 683829    none  hsa04060:Cytokine-cytokineReceptorInteraction;...    none
# 683830    none  hsa04060:Cytokine-cytokineReceptorInteraction;...    none
#
#         unknown.3 unknown.4  \
# 683826    unknown   unknown
# 683827    unknown   unknown
# 683828    unknown   unknown
# 683829    unknown   unknown
# 683830    unknown   unknown
#
#                                                    none.7 NA.5
# 683826  IL9:989,IL2RG:969,JAK1:956,JAK3:934,STAT5A:934...  NaN
# 683827  IL9:989,IL2RG:969,JAK1:956,JAK3:934,STAT5A:934...  NaN
# 683828  IL9:989,IL2RG:969,JAK1:956,JAK3:934,STAT5A:934...  NaN
# 683829  IL9:989,IL2RG:969,JAK1:956,JAK3:934,STAT5A:934...  NaN
# 683830  IL9:989,IL2RG:969,JAK1:956,JAK3:934,STAT5A:934...  NaN
#
# [5 rows x 32 columns]
# Index(['dbSNP_2002', '1', '817341', 'A', 'R', 'A/G', 'A/C/G/T', 'none',
#        'upstream-gene', 'upstream_transcript_variant', '3131972', 'none.1',
#        'NA', 'NA.1', 'unknown', 'NA.2', 'NA.3', '3.952', 'A.1', 'none.2',
#        'NA.4', 'none.3', 'none.4', 'unknown.1', '862', 'none.5', 'unknown.2',
#        'none.6', 'unknown.3', 'unknown.4', 'none.7', 'NA.5'],
#       dtype='object')
# (683831, 32)
# dbSNP_2002                          0
# 1                                   0
# 817341                              0
# A                                   0
# R                                   0
# A/G                                 0
# A/C/G/T                             0
# none                                0
# upstream-gene                       0
# upstream_transcript_variant         0
# 3131972                             0
# none.1                              0
# NA                             660384
# NA.1                           657784
# unknown                             0
# NA.2                           668999
# NA.3                            12283
# 3.952                               0
# A.1                                 0
# none.2                              0
# NA.4                           683831
# none.3                              0
# none.4                              0
# unknown.1                           0
# 862                                 0
# none.5                              0
# unknown.2                           0
# none.6                              0
# unknown.3                           0
# unknown.4                           0
# none.7                              0
# NA.5                           660311
# dtype: int64
# 0
# ['dbSNP_2002', '1', '817341', 'A', 'R', 'A/G', 'A/C/G/T', 'none', 'upstream-gene', 'upstream_transcript_variant', '3131972', 'none.1', 'NA', 'NA.1', 'unknown', 'NA.2', 'NA.3', '3.952', 'A.1', 'none.2', 'NA.4', 'none.3', 'none.4', 'unknown.1', '862', 'none.5', 'unknown.2', 'none.6', 'unknown.3', 'unknown.4', 'none.7', 'NA.5']
# dbSNP_2002                      object
# 1                               object
# 817341                           int64
# A                               object
# R                               object
# A/G                             object
# A/C/G/T                         object
# none                            object
# upstream-gene                   object
# upstream_transcript_variant     object
# 3131972                          int64
# none.1                          object
# NA                              object
# NA.1                           float64
# unknown                         object
# NA.2                           float64
# NA.3                           float64
# 3.952                           object
# A.1                             object
# none.2                          object
# NA.4                           float64
# none.3                          object
# none.4                          object
# unknown.1                       object
# 862                              int64
# none.5                          object
# unknown.2                       object
# none.6                          object
# unknown.3                       object
# unknown.4                       object
# none.7                          object
# NA.5                            object
# dtype: object
# Index                               132
# dbSNP_2002                     40270381
# 1                              25030463
# 817341                          5470648
# A                              34191550
# R                              34191550
# A/G                            35559212
# A/C/G/T                        36411066
# none                           41948215
# upstream-gene                  38165194
# upstream_transcript_variant    42791617
# 3131972                         5470648
# none.1                         36279211
# NA                             22455758
# NA.1                            5470648
# unknown                        38242001
# NA.2                            5470648
# NA.3                            5470648
# 3.952                          34817845
# A.1                            34214008
# none.2                         37379915
# NA.4                            5470648
# none.3                         36453329
# none.4                         36245521
# unknown.1                      40784396
# 862                             5470648
# none.5                         36243295
# unknown.2                      53286369
# none.6                         36296256
# unknown.3                      38531131
# unknown.4                      38632363
# none.7                         77012494
# NA.5                           22600093
# dtype: int64
#         dbSNP_2002   1     817341  A  R  A/G A/C/G/T            none  \
# 113349  dbSNP_2003   3   17512689  C  Y  C/T     C/T  NM_001349079.1
# 556501  dbSNP_2004  15   95494228  C  Y  C/T     C/T     NR_027133.1
# 324897  dbSNP_2009   8   32755631  G  R  G/A     G/A  XM_017013365.2
# 36028   dbSNP_2001   1  207756858  G  A  A/A     G/A     NM_172353.3
# 172740  dbSNP_2003   4   47703561  G  R  G/A     G/A  NM_001278585.1
#
#        upstream-gene upstream_transcript_variant  ...  none.4  \
# 113349        intron              intron_variant  ...    none
# 556501        intron              intron_variant  ...    none
# 324897        intron              intron_variant  ...    none
# 36028         intron              intron_variant  ...    none
# 172740        intron              intron_variant  ...    none
#
#                                                 unknown.1    862  none.5  \
# 113349                                            unknown   4082    none
# 556501                                            unknown   3451    none
# 324897                                            unknown    770    none
# 36028   http://www.ncbi.nlm.nih.gov/pubmed?term=253446...    154    none
# 172740                                            unknown  10476    none
#
#                                         unknown.2  none.6  unknown.3  \
# 113349                                    unknown    none    unknown
# 556501                                    unknown    none    unknown
# 324897              hsa04012:ErbBSignalingPathway    none    unknown
# 36028   hsa04610:ComplementAndCoagulationCascades    none    unknown
# 172740                                    unknown    none    unknown
#
#        unknown.4                                             none.7 NA.5
# 113349   unknown  VPS29:999,VPS26A:994,VPS26B:986,VPS35:968,SNX1...  NaN
# 556501   unknown                                               none  NaN
# 324897   unknown  ERBB4:998,ERBB3:997,EGFR:994,ERBB2:992,EGF:982...  NaN
# 36028    unknown  C3:998,C4B:992,C4A:988,CFI:977,C2:945,CFB:929,...  NaN
# 172740   unknown                                           NPPA:968  NaN
#
# [5 rows x 32 columns]
#         dbSNP_2002   1     817341  A  R  A/G A/C/G/T            none  \
# 642505  dbSNP_2009  20    9307153  C  Y  C/T     C/T  XM_005260724.2
# 260386  dbSNP_2000   6  133394284  G  R  G/A   G/A/T     NM_172103.3
# 321307  dbSNP_2004   8   19677034  G  A  A/A     G/A  NM_001354487.1
# 485871  dbSNP_2004  12   81736586  T  K  T/G     T/G  XM_017020083.2
# 398288  dbSNP_2004  10   49154447  G  R  G/A     G/A            none
# ...            ...  ..        ... .. ..  ...     ...             ...
# 68944   dbSNP_2003   2   77897849  T  C  C/C   T/A/C     NR_110288.1
# 434017  dbSNP_2003  11   15670682  T  Y  T/C   T/A/C  NM_001293172.1
# 603078  dbSNP_2000  17   81193028  G  R  G/A   G/A/C  XM_011524555.2
# 143753  dbSNP_2000   3  139527540  A  G  G/G     A/G  NM_001130993.2
# 91078   dbSNP_2000   2  197749888  C  T  T/T     C/T     NM_033030.6
#
#           upstream-gene upstream_transcript_variant  ...  none.4 unknown.1  \
# 642505           intron              intron_variant  ...    none   unknown
# 260386           intron              intron_variant  ...    none   unknown
# 321307           intron              intron_variant  ...    none   unknown
# 485871           intron              intron_variant  ...    none   unknown
# 398288  downstream-gene                        none  ...    none   unknown
# ...                 ...                         ...  ...     ...       ...
# 68944            intron              intron_variant  ...    none   unknown
# 434017           intron              intron_variant  ...    none   unknown
# 603078           intron              intron_variant  ...    none   unknown
# 143753           intron              intron_variant  ...    none   unknown
# 91078            intron              intron_variant  ...    none   unknown
#
#           862  none.5                                          unknown.2  \
# 642505    645    none  hsa00562:InositolPhosphateMetabolism;hsa01100:...
# 260386  11841    none                                            unknown
# 321307   5437    none  hsa00532:GlycosaminoglycanBiosynthesis-Chondro...
# 485871  17385    none                                            unknown
# 398288    519    none                                            unknown
# ...       ...     ...                                                ...
# 68944   18245    none                                            unknown
# 434017  26645    none                                            unknown
# 603078    183    none                                            unknown
# 143753    196    none                                            unknown
# 91078    6040    none                                            unknown
#
#         none.6  unknown.3 unknown.4  \
# 642505    none    unknown   unknown
# 260386    none    unknown   unknown
# 321307    none    unknown   unknown
# 485871    none    unknown   unknown
# 398288    none    unknown   unknown
# ...        ...        ...       ...
# 68944     none    unknown   unknown
# 434017    none    unknown   unknown
# 603078    none    unknown   unknown
# 143753    none    unknown   unknown
# 91078     none    unknown   unknown
#
#                                                    none.7 NA.5
# 642505  GNAQ:968,GNAI3:967,GNA11:962,ITPR3:952,CYSLTR2...  NaN
# 260386  DACH1:948,H2AFX:912,EYA1:907,MDC1:907,SIX1:906...  NaN
# 321307  B3GAT3:956,CHPF:953,CHPF2:951,VCAN:936,BCAN:93...  NaN
# 485871  CASK:987,PTPRF:974,RIMS1:965,LIN7A:960,PTPRD:9...  NaN
# 398288                                               none  NaN
# ...                                                   ...  ...
# 68944                                                none  NaN
# 434017                                               none  NaN
# 603078  CEP290:981,PCM1:973,OFD1:973,CEP152:971,PCNT:9...  NaN
# 143753  LRAT:989,RDH11:974,STRA6:974,RDH10:968,RBP4:96...  NaN
# 91078   CPEB1:912,CDC20B:870,UBA5:865,CDC25A:816,DAZAP...  NaN
#
# [68383 rows x 32 columns]

# %%
## Save As Excel
df.to_excel('genome_hu0B4CF6_out.xlsx', index=False)

# %%
# Get List of vlaues in aminoAcids column
aminoAcids = df['aminoAcids'].tolist()

# Get counts of each amino acid
aminoAcidCounts = df['aminoAcids'].value_counts()

#Export counts
aminoAcidCounts.to_csv('aminoAcidCounts.csv', index=True)



# Split amino acids based on comma
aminoAcids_split = [x.split(',') for x in aminoAcids]
# remove duplicates
aminoAcids = list(set(aminoAcids))
# Remove None
aminoAcids = [x for x in aminoAcids if x is not None]

# %% [raw]
# Index(['# inDBSNPOrNot', 'chromosome', 'position', 'referenceBase',
#        'sampleGenotype', 'sampleAlleles', 'allelesDBSNP', 'accession',
#        'functionGVS', 'functionDBSNP', 'rsID', 'aminoAcids', 'proteinPosition',
#        'cDNAPosition', 'polyPhen', 'granthamScore', 'consScoreGERP',
#        'scoreCADD', 'chimpAllele', 'geneList', 'dbSNPValidation',
#        'repeatMasker', 'tandemRepeat', 'clinicalAssociation',
#        'distanceToSplice', 'microRNAs', 'keggPathway', 'cpgIslands',
#        'genomesESP', 'genomesExAC', 'PPI', 'proteinAccession'],
#       dtype='object')

# %%
high_impact = df[(df['functionGVS'] == 'missense') & 
                       (df['polyPhen'] > 0.85) & 
                       (df['granthamScore'] > 100) &
                       (df['scoreCADD'] > 20)]

priority_variants = pd.concat([high_impact]).drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 high_impact = df[(df['functionGVS'] == 'missense') &
# ----> 2                        (df['polyPhen'] > 0.85) &
#       3                        (df['granthamScore'] > 100) &
#       4                        (df['scoreCADD'] > 20)]
#       6 priority_variants = pd.concat([high_impact]).drop_duplicates()
#
# File ~/venv/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/venv/lib/python3.12/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~/venv/lib/python3.12/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~/venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/venv/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %%
# Filter Data -= functionDBSNP != "unknown"
df_filtered = df[df['functionDBSNP'] != "unknown"]

# Filter Data - geneList == KIT
df_filtered = df_filtered[df_filtered['geneList'] == "KIT"]


# Write csv
df_filtered.to_csv('dataFiltered_KIT.csv', index=False)
